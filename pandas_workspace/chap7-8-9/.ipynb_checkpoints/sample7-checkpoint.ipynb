# %%
import pandas as pd

# %%
df_pew = pd.read_csv('../doit_pandas/data/pew.csv')

# %%
df_pew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 11 columns):
# religion              18 non-null object
# <$10k                 18 non-null int64
# $10-20k               18 non-null int64
# $20-30k               18 non-null int64
# $30-40k               18 non-null int64
# $40-50k               18 non-null int64
# $50-75k               18 non-null int64
# $75-100k              18 non-null int64
# $100-150k             18 non-null int64
# >150k                 18 non-null int64
# Don't know/refused    18 non-null int64
# dtypes: int64(10), object(1)
# memory usage: 1.7+ KB

# %%
df_pew.head()
# Out:
#              religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# 0            Agnostic     27       34       60       81       76      137
# 1             Atheist     12       27       37       52       35       70
# 2            Buddhist     27       21       30       34       33       58
# 3            Catholic    418      617      732      670      638     1116
# 4  Don’t know/refused     15       14       15       11       10       35
#
#    $75-100k  $100-150k  >150k  Don't know/refused
# 0       122        109     84                  96
# 1        73         59     74                  76
# 2        62         39     53                  54
# 3       949        792    633                1489
# 4        21         17     18                 116

# %%
df_pew.columns
# Out:
# Index(['religion', '<$10k', '$10-20k', '$20-30k', '$30-40k', '$40-50k',
#        '$50-75k', '$75-100k', '$100-150k', '>150k', 'Don't know/refused'],
#       dtype='object')

# %%
list(df_pew.columns)
# Out:
# ['religion',
#  '<$10k',
#  '$10-20k',
#  '$20-30k',
#  '$30-40k',
#  '$40-50k',
#  '$50-75k',
#  '$75-100k',
#  '$100-150k',
#  '>150k',
#  "Don't know/refused"]

# %%
df_pew.iloc[:, :6]
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
pd.melt(df_pew, id_vars='religion')
# Out:
#                   religion            variable  value
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
df_pew_long = pd.melt(df_pew, id_vars=['religion'])

# %%
df_pew_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 3 columns):
# religion    180 non-null object
# variable    180 non-null object
# value       180 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 4.3+ KB

# %%
df_pew_long.head()
# Out:
#              religion variable  value
# 0            Agnostic    <$10k     27
# 1             Atheist    <$10k     12
# 2            Buddhist    <$10k     27
# 3            Catholic    <$10k    418
# 4  Don’t know/refused    <$10k     15

# %%
df_pew_long[df_pew_long['religion'] == 'Catholic']
# Out:
#      religion            variable  value
# 3    Catholic               <$10k    418
# 21   Catholic             $10-20k    617
# 39   Catholic             $20-30k    732
# 57   Catholic             $30-40k    670
# 75   Catholic             $40-50k    638
# 93   Catholic             $50-75k   1116
# 111  Catholic            $75-100k    949
# 129  Catholic           $100-150k    792
# 147  Catholic               >150k    633
# 165  Catholic  Don't know/refused   1489

# %%
df_billboard = pd.read_csv('../doit_pandas/data/billboard.csv')

# %%
df_billboard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 81 columns):
# year            317 non-null int64
# artist          317 non-null object
# track           317 non-null object
# time            317 non-null object
# date.entered    317 non-null object
# wk1             317 non-null int64
# wk2             312 non-null float64
# wk3             307 non-null float64
# wk4             300 non-null float64
# wk5             292 non-null float64
# wk6             280 non-null float64
# wk7             269 non-null float64
# wk8             260 non-null float64
# wk9             253 non-null float64
# wk10            244 non-null float64
# wk11            236 non-null float64
# wk12            222 non-null float64
# wk13            210 non-null float64
# wk14            204 non-null float64
# wk15            197 non-null float64
# wk16            182 non-null float64
# wk17            177 non-null float64
# wk18            166 non-null float64
# ...

# %%
df_billboard.head()
# Out:
#    year        artist                    track  time date.entered  wk1   wk2  \
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87  82.0
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91  87.0
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08   81  70.0
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21   76  76.0
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15   57  34.0
#
#     wk3   wk4   wk5  ...  wk67  wk68  wk69  wk70  wk71  wk72  wk73  wk74  \
# 0  72.0  77.0  87.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  92.0   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  68.0  67.0  66.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  72.0  69.0  67.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  25.0  17.0  17.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    wk75  wk76
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# ...

# %%
df_billboard.iloc[0:5, :16]
# Out:
#    year        artist                    track  time date.entered  wk1   wk2  \
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87  82.0
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91  87.0
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08   81  70.0
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21   76  76.0
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15   57  34.0
#
#     wk3   wk4   wk5   wk6   wk7   wk8   wk9  wk10  wk11
# 0  72.0  77.0  87.0  94.0  99.0   NaN   NaN   NaN   NaN
# 1  92.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  68.0  67.0  66.0  57.0  54.0  53.0  51.0  51.0  51.0
# 3  72.0  69.0  67.0  65.0  55.0  59.0  62.0  61.0  61.0
# 4  25.0  17.0  17.0  31.0  36.0  49.0  53.0  57.0  64.0

# %%
pd.melt(df_billboard, id_vars=['year', 'artist', 'track', 'time', 'date.entered'])
# Out:
#        year            artist                    track  time date.entered  \
# 0      2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 1      2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02
# 2      2000      3 Doors Down               Kryptonite  3:53   2000-04-08
# 3      2000      3 Doors Down                    Loser  4:24   2000-10-21
# 4      2000          504 Boyz            Wobble Wobble  3:35   2000-04-15
# ...     ...               ...                      ...   ...          ...
# 24087  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29
# 24088  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01
# 24089  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18
# 24090  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02
# 24091  2000   matchbox twenty                     Bent  4:12   2000-04-29
#
#       variable  value
# 0          wk1   87.0
# 1          wk1   91.0
# ...

# %%
df_billboard_long = pd.melt(df_billboard, id_vars=['year', 'artist', 'track', 'time', 'date.entered'])

# %%
df_billboard_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24092 entries, 0 to 24091
# Data columns (total 7 columns):
# year            24092 non-null int64
# artist          24092 non-null object
# track           24092 non-null object
# time            24092 non-null object
# date.entered    24092 non-null object
# variable        24092 non-null object
# value           5307 non-null float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.3+ MB

# %%
df_billboard_long.head()
# Out:
#    year        artist                    track  time date.entered variable  \
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26      wk1
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02      wk1
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08      wk1
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21      wk1
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15      wk1
#
#    value
# 0   87.0
# 1   91.0
# 2   81.0
# 3   76.0
# 4   57.0

# %%
df_billboard_long = pd.melt(df_billboard, id_vars=[
    'year', 'artist', 'track', 'time', 'date.entered'
], var_name = 'week', value_name = 'rating')

# %%
df_billboard_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24092 entries, 0 to 24091
# Data columns (total 7 columns):
# year            24092 non-null int64
# artist          24092 non-null object
# track           24092 non-null object
# time            24092 non-null object
# date.entered    24092 non-null object
# week            24092 non-null object
# rating          5307 non-null float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.3+ MB

# %%
df_billboard_long.head()
# Out:
#    year        artist                    track  time date.entered week  rating
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk1    87.0
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk1    91.0
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08  wk1    81.0
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21  wk1    76.0
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15  wk1    57.0

# %%
df_billboard_long = pd.melt(df_billboard, value_vars=[
    'wk1', 'wk2'
])

# %%
df_billboard_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 2 columns):
# variable    634 non-null object
# value       629 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 10.0+ KB

# %%
df_billboard_long.head()
# Out:
#   variable  value
# 0      wk1   87.0
# 1      wk1   91.0
# 2      wk1   81.0
# 3      wk1   76.0
# 4      wk1   57.0

# %%
df_billboard_long.tail()
# Out:
#     variable  value
# 629      wk2   83.0
# 630      wk2   83.0
# 631      wk2   94.0
# 632      wk2   99.0
# 633      wk2   37.0

# %%
df_billboard_wk1_long = pd.melt(df_billboard, value_vars='wk1', var_name='Week1', value_name='Rating')

# %%
df_billboard_wk1_long
# Out:
#     Week1  Rating
# 0     wk1      87
# 1     wk1      91
# 2     wk1      81
# 3     wk1      76
# 4     wk1      57
# ..    ...     ...
# 312   wk1      86
# 313   wk1      85
# 314   wk1      95
# 315   wk1      99
# 316   wk1      60
#
# [317 rows x 2 columns]

# %%
df_ebola = pd.read_csv('../doit_pandas/data/country_timeseries.csv')

# %%
df_ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
# Date                   122 non-null object
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# dtypes: float64(16), int64(1), object(1)
# memory usage: 17.3+ KB

# %%
df_ebola.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
df_ebola.columns
# Out:
# Index(['Date', 'Day', 'Cases_Guinea', 'Cases_Liberia', 'Cases_SierraLeone',
#        'Cases_Nigeria', 'Cases_Senegal', 'Cases_UnitedStates', 'Cases_Spain',
#        'Cases_Mali', 'Deaths_Guinea', 'Deaths_Liberia', 'Deaths_SierraLeone',
#        'Deaths_Nigeria', 'Deaths_Senegal', 'Deaths_UnitedStates',
#        'Deaths_Spain', 'Deaths_Mali'],
#       dtype='object')

# %%
df_ebola.iloc[:5, [0:4, 10, 11]]
# Out:
#   File "<ipython-input-38-f7c34895948c>", line 1
#     df_ebola.iloc[:5, [0:4, 10, 11]]
#                         ^
# SyntaxError: invalid syntax

# %%
df_ebola.iloc[:5, [0,1,2,3,10,11]]
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Deaths_Guinea  Deaths_Liberia
# 0    1/5/2015  289        2776.0            NaN         1786.0             NaN
# 1    1/4/2015  288        2775.0            NaN         1781.0             NaN
# 2    1/3/2015  287        2769.0         8166.0         1767.0          3496.0
# 3    1/2/2015  286           NaN         8157.0            NaN          3496.0
# 4  12/31/2014  284        2730.0         8115.0         1739.0          3471.0

# %%
df_ebola_long = pd.melt(df_ebola, id_vars=['Date', 'Day'])

# %%
df_ebola_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 4 columns):
# Date        1952 non-null object
# Day         1952 non-null int64
# variable    1952 non-null object
# value       738 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 61.1+ KB

# %%
df_ebola_long.head()
# Out:
#          Date  Day      variable   value
# 0    1/5/2015  289  Cases_Guinea  2776.0
# 1    1/4/2015  288  Cases_Guinea  2775.0
# 2    1/3/2015  287  Cases_Guinea  2769.0
# 3    1/2/2015  286  Cases_Guinea     NaN
# 4  12/31/2014  284  Cases_Guinea  2730.0

# %%
df_ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
# Date                   122 non-null object
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# dtypes: float64(16), int64(1), object(1)
# memory usage: 17.3+ KB

# %%
df_ebola_long.columns
# Out:
# Index(['Date', 'Day', 'variable', 'value'], dtype='object')

# %%
df_ebola_long.variable
# Out:
# 0       Cases_Guinea
# 1       Cases_Guinea
# 2       Cases_Guinea
# 3       Cases_Guinea
# 4       Cases_Guinea
#             ...
# 1947     Deaths_Mali
# 1948     Deaths_Mali
# 1949     Deaths_Mali
# 1950     Deaths_Mali
# 1951     Deaths_Mali
# Name: variable, Length: 1952, dtype: object

# %%
df_ebola_long.variable.unique()
# Out:
# array(['Cases_Guinea', 'Cases_Liberia', 'Cases_SierraLeone',
#        'Cases_Nigeria', 'Cases_Senegal', 'Cases_UnitedStates',
#        'Cases_Spain', 'Cases_Mali', 'Deaths_Guinea', 'Deaths_Liberia',
#        'Deaths_SierraLeone', 'Deaths_Nigeria', 'Deaths_Senegal',
#        'Deaths_UnitedStates', 'Deaths_Spain', 'Deaths_Mali'], dtype=object)

# %%
list(df_ebola_long.variable.unique())
# Out:
# ['Cases_Guinea',
#  'Cases_Liberia',
#  'Cases_SierraLeone',
#  'Cases_Nigeria',
#  'Cases_Senegal',
#  'Cases_UnitedStates',
#  'Cases_Spain',
#  'Cases_Mali',
#  'Deaths_Guinea',
#  'Deaths_Liberia',
#  'Deaths_SierraLeone',
#  'Deaths_Nigeria',
#  'Deaths_Senegal',
#  'Deaths_UnitedStates',
#  'Deaths_Spain',
#  'Deaths_Mali']

# %%
df_ebola_long.variable.nunique()
# Out:
# 16

# %%
df_ebola_long.variable.str

# %%
df_ebola_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 4 columns):
# Date        1952 non-null object
# Day         1952 non-null int64
# variable    1952 non-null object
# value       738 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 61.1+ KB

# %%
df_ebola_long.value.str
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-4ce83284de6e> in <module>
# ----> 1 df_ebola_long.value.str
#
# C:\app\python3.7.3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# C:\app\python3.7.3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
#     176         # Replace the property with the accessor object. Inspired by:
#     177         # http://www.pydanny.com/cached-property.html
#
# ...

# %%
df_ebola_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 4 columns):
# Date        1952 non-null object
# Day         1952 non-null int64
# variable    1952 non-null object
# value       738 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 61.1+ KB

# %%
type( df_ebola_long.variable.str.split('_') )
# Out:
# pandas.core.series.Series

# %%
df_ebola_long.head()
# Out:
#          Date  Day      variable   value
# 0    1/5/2015  289  Cases_Guinea  2776.0
# 1    1/4/2015  288  Cases_Guinea  2775.0
# 2    1/3/2015  287  Cases_Guinea  2769.0
# 3    1/2/2015  286  Cases_Guinea     NaN
# 4  12/31/2014  284  Cases_Guinea  2730.0

# %%
type( 'Cases_Guinea'.split('_') )
# Out:
# list

# %%
s_variable_split = df_ebola_long.variable.str.split('_')

# %%
type(s_variable_split)
# Out:
# pandas.core.series.Series

# %%
s_variable_split
# Out:
# 0       [Cases, Guinea]
# 1       [Cases, Guinea]
# 2       [Cases, Guinea]
# 3       [Cases, Guinea]
# 4       [Cases, Guinea]
#              ...
# 1947     [Deaths, Mali]
# 1948     [Deaths, Mali]
# 1949     [Deaths, Mali]
# 1950     [Deaths, Mali]
# 1951     [Deaths, Mali]
# Name: variable, Length: 1952, dtype: object

# %%
s_variable_split[0:5]
# Out:
# 0    [Cases, Guinea]
# 1    [Cases, Guinea]
# 2    [Cases, Guinea]
# 3    [Cases, Guinea]
# 4    [Cases, Guinea]
# Name: variable, dtype: object

# %%
s_variable_split.str.get(1)
# Out:
# 0       Guinea
# 1       Guinea
# 2       Guinea
# 3       Guinea
# 4       Guinea
#          ...
# 1947      Mali
# 1948      Mali
# 1949      Mali
# 1950      Mali
# 1951      Mali
# Name: variable, Length: 1952, dtype: object

# %%
s_variable_split.get([0,1,2])
# Out:
# 0    [Cases, Guinea]
# 1    [Cases, Guinea]
# 2    [Cases, Guinea]
# Name: variable, dtype: object

# %%
s_cases = s_variable_split.str.get(0)

# %%
s_cases
# Out:
# 0        Cases
# 1        Cases
# 2        Cases
# 3        Cases
# 4        Cases
#          ...
# 1947    Deaths
# 1948    Deaths
# 1949    Deaths
# 1950    Deaths
# 1951    Deaths
# Name: variable, Length: 1952, dtype: object

# %%
del s_cases

# %%
s_status = s_variable_split.str.get(0)

# %%
s_country = s_variable_split.str.get(1)

# %%
s_country
# Out:
# 0       Guinea
# 1       Guinea
# 2       Guinea
# 3       Guinea
# 4       Guinea
#          ...
# 1947      Mali
# 1948      Mali
# 1949      Mali
# 1950      Mali
# 1951      Mali
# Name: variable, Length: 1952, dtype: object

# %%
del s_values

# %%
df_ebola_long['status'] = s_status

# %%
df_ebola_long['country'] = s_country

# %%
df_ebola_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 6 columns):
# Date        1952 non-null object
# Day         1952 non-null int64
# variable    1952 non-null object
# value       738 non-null float64
# status      1952 non-null object
# country     1952 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 91.6+ KB

# %%
df_ebola_long.head()
# Out:
#          Date  Day      variable   value status country
# 0    1/5/2015  289  Cases_Guinea  2776.0  Cases  Guinea
# 1    1/4/2015  288  Cases_Guinea  2775.0  Cases  Guinea
# 2    1/3/2015  287  Cases_Guinea  2769.0  Cases  Guinea
# 3    1/2/2015  286  Cases_Guinea     NaN  Cases  Guinea
# 4  12/31/2014  284  Cases_Guinea  2730.0  Cases  Guinea

# %%
type( df_ebola_long.variable.str.split('_', expand=True) )
# Out:
# pandas.core.frame.DataFrame

# %%
df_variable_split = df_ebola_long.variable.str.split('_', expand=True)

# %%
df_variable_split.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 2 columns):
# 0    1952 non-null object
# 1    1952 non-null object
# dtypes: object(2)
# memory usage: 30.6+ KB

# %%
df_variable_split.head()
# Out:
#        0       1
# 0  Cases  Guinea
# 1  Cases  Guinea
# 2  Cases  Guinea
# 3  Cases  Guinea
# 4  Cases  Guinea

# %%
df_variable_split.columns = ['status', 'country']

# %%
df_ebola_parsed = pd.concat([df_ebola_long, df_variable_split], axis = 1)

# %%
df_ebola_parsed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 8 columns):
# Date        1952 non-null object
# Day         1952 non-null int64
# variable    1952 non-null object
# value       738 non-null float64
# status      1952 non-null object
# country     1952 non-null object
# status      1952 non-null object
# country     1952 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 122.1+ KB

# %%
df_ebola_parsed.head()
# Out:
#          Date  Day      variable   value status country status country
# 0    1/5/2015  289  Cases_Guinea  2776.0  Cases  Guinea  Cases  Guinea
# 1    1/4/2015  288  Cases_Guinea  2775.0  Cases  Guinea  Cases  Guinea
# 2    1/3/2015  287  Cases_Guinea  2769.0  Cases  Guinea  Cases  Guinea
# 3    1/2/2015  286  Cases_Guinea     NaN  Cases  Guinea  Cases  Guinea
# 4  12/31/2014  284  Cases_Guinea  2730.0  Cases  Guinea  Cases  Guinea

# %%
df_weather = pd.read_csv('../doit_pandas/data/weather.csv')

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 35 columns):
# id         22 non-null object
# year       22 non-null int64
# month      22 non-null int64
# element    22 non-null object
# d1         2 non-null float64
# d2         4 non-null float64
# d3         4 non-null float64
# d4         2 non-null float64
# d5         8 non-null float64
# d6         2 non-null float64
# d7         2 non-null float64
# d8         2 non-null float64
# d9         0 non-null float64
# d10        2 non-null float64
# d11        2 non-null float64
# d12        0 non-null float64
# d13        2 non-null float64
# d14        4 non-null float64
# d15        2 non-null float64
# d16        2 non-null float64
# d17        2 non-null float64
# d18        0 non-null float64
# d19        0 non-null float64
# d20        0 non-null float64
# d21        0 non-null float64
# d22        0 non-null float64
# d23        4 non-null float64
# ...

# %%
df_weather.head()
# Out:
#         id  year  month element  d1    d2    d3  d4    d5  d6  ...  d22   d23  \
# 0  MX17004  2010      1    tmax NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 1  MX17004  2010      1    tmin NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 2  MX17004  2010      2    tmax NaN  27.3  24.1 NaN   NaN NaN  ...  NaN  29.9
# 3  MX17004  2010      2    tmin NaN  14.4  14.4 NaN   NaN NaN  ...  NaN  10.7
# 4  MX17004  2010      3    tmax NaN   NaN   NaN NaN  32.1 NaN  ...  NaN   NaN
#
#    d24  d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  14.5  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 35 columns]

# %%
df_weather.iloc[:5, :]
# Out:
#         id  year  month element  d1    d2    d3  d4    d5  d6  ...  d22   d23  \
# 0  MX17004  2010      1    tmax NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 1  MX17004  2010      1    tmin NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 2  MX17004  2010      2    tmax NaN  27.3  24.1 NaN   NaN NaN  ...  NaN  29.9
# 3  MX17004  2010      2    tmin NaN  14.4  14.4 NaN   NaN NaN  ...  NaN  10.7
# 4  MX17004  2010      3    tmax NaN   NaN   NaN NaN  32.1 NaN  ...  NaN   NaN
#
#    d24  d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  14.5  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 35 columns]

# %%
df_weather_melt = pd.melt(df_weather, id_vars = ['id', 'year', 'month', 'element'])

# %%
df_weather_melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 6 columns):
# id          682 non-null object
# year        682 non-null int64
# month       682 non-null int64
# element     682 non-null object
# variable    682 non-null object
# value       66 non-null float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 32.1+ KB

# %%
df_weather_melt.iloc[:5]
# Out:
#         id  year  month element variable  value
# 0  MX17004  2010      1    tmax       d1    NaN
# 1  MX17004  2010      1    tmin       d1    NaN
# 2  MX17004  2010      2    tmax       d1    NaN
# 3  MX17004  2010      2    tmin       d1    NaN
# 4  MX17004  2010      3    tmax       d1    NaN

# %%
df_weather_melt.iloc[:]
# Out:
#           id  year  month element variable  value
# 0    MX17004  2010      1    tmax       d1    NaN
# 1    MX17004  2010      1    tmin       d1    NaN
# 2    MX17004  2010      2    tmax       d1    NaN
# 3    MX17004  2010      2    tmin       d1    NaN
# 4    MX17004  2010      3    tmax       d1    NaN
# ..       ...   ...    ...     ...      ...    ...
# 677  MX17004  2010     10    tmin      d31    NaN
# 678  MX17004  2010     11    tmax      d31    NaN
# 679  MX17004  2010     11    tmin      d31    NaN
# 680  MX17004  2010     12    tmax      d31    NaN
# 681  MX17004  2010     12    tmin      d31    NaN
#
# [682 rows x 6 columns]

# %%
df_weather_melt.iloc[:,:]
# Out:
#           id  year  month element variable  value
# 0    MX17004  2010      1    tmax       d1    NaN
# 1    MX17004  2010      1    tmin       d1    NaN
# 2    MX17004  2010      2    tmax       d1    NaN
# 3    MX17004  2010      2    tmin       d1    NaN
# 4    MX17004  2010      3    tmax       d1    NaN
# ..       ...   ...    ...     ...      ...    ...
# 677  MX17004  2010     10    tmin      d31    NaN
# 678  MX17004  2010     11    tmax      d31    NaN
# 679  MX17004  2010     11    tmin      d31    NaN
# 680  MX17004  2010     12    tmax      d31    NaN
# 681  MX17004  2010     12    tmin      d31    NaN
#
# [682 rows x 6 columns]

# %%
df_weather_melt.loc[df_weather_melt['element'] == 'tmin']
# Out:
#           id  year  month element variable  value
# 1    MX17004  2010      1    tmin       d1    NaN
# 3    MX17004  2010      2    tmin       d1    NaN
# 5    MX17004  2010      3    tmin       d1    NaN
# 7    MX17004  2010      4    tmin       d1    NaN
# 9    MX17004  2010      5    tmin       d1    NaN
# ..       ...   ...    ...     ...      ...    ...
# 673  MX17004  2010      7    tmin      d31    NaN
# 675  MX17004  2010      8    tmin      d31   15.4
# 677  MX17004  2010     10    tmin      d31    NaN
# 679  MX17004  2010     11    tmin      d31    NaN
# 681  MX17004  2010     12    tmin      d31    NaN
#
# [341 rows x 6 columns]

# %%
df_weather_melt
# Out:
#           id  year  month element variable  value
# 0    MX17004  2010      1    tmax       d1    NaN
# 1    MX17004  2010      1    tmin       d1    NaN
# 2    MX17004  2010      2    tmax       d1    NaN
# 3    MX17004  2010      2    tmin       d1    NaN
# 4    MX17004  2010      3    tmax       d1    NaN
# ..       ...   ...    ...     ...      ...    ...
# 677  MX17004  2010     10    tmin      d31    NaN
# 678  MX17004  2010     11    tmax      d31    NaN
# 679  MX17004  2010     11    tmin      d31    NaN
# 680  MX17004  2010     12    tmax      d31    NaN
# 681  MX17004  2010     12    tmin      d31    NaN
#
# [682 rows x 6 columns]

# %%
df_weather_melt.columns = ['id', 'year', 'month', 'element', 'day', 'temp']

# %%
df_weather_melt.columns
# Out:
# Index(['id', 'year', 'month', 'element', 'day', 'temp'], dtype='object')

# %%
df_weather_melt
# Out:
#           id  year  month element  day  temp
# 0    MX17004  2010      1    tmax   d1   NaN
# 1    MX17004  2010      1    tmin   d1   NaN
# 2    MX17004  2010      2    tmax   d1   NaN
# 3    MX17004  2010      2    tmin   d1   NaN
# 4    MX17004  2010      3    tmax   d1   NaN
# ..       ...   ...    ...     ...  ...   ...
# 677  MX17004  2010     10    tmin  d31   NaN
# 678  MX17004  2010     11    tmax  d31   NaN
# 679  MX17004  2010     11    tmin  d31   NaN
# 680  MX17004  2010     12    tmax  d31   NaN
# 681  MX17004  2010     12    tmin  d31   NaN
#
# [682 rows x 6 columns]

# %%
df_weather_tidy = df_weather_melt.pivot_table(
    index = ['id', 'year', 'month', 'day'],
    columns = 'element'
    ,values = 'temp'
)

# %%
type(df_weather_tidy)
# Out:
# pandas.core.frame.DataFrame

# %%
df_weather_tidy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 33 entries, (MX17004, 2010, 1, d30) to (MX17004, 2010, 12, d6)
# Data columns (total 2 columns):
# tmax    33 non-null float64
# tmin    33 non-null float64
# dtypes: float64(2)
# memory usage: 1.2+ KB

# %%
df_weather_tidy
# Out:
# element                 tmax  tmin
# id      year month day
# MX17004 2010 1     d30  27.8  14.5
#              2     d11  29.7  13.4
#                    d2   27.3  14.4
#                    d23  29.9  10.7
#                    d3   24.1  14.4
#              3     d10  34.5  16.8
#                    d16  31.1  17.6
#                    d5   32.1  14.2
#              4     d27  36.3  16.7
#              5     d27  33.2  18.2
#              6     d17  28.0  17.5
#                    d29  30.1  18.0
#              7     d3   28.6  17.5
#                    d14  29.9  16.5
#              8     d23  26.4  15.0
#                    d5   29.6  15.8
#                    d29  28.0  15.3
#                    d13  29.8  16.5
#                    d25  29.7  15.6
#                    d31  25.4  15.4
#                    d8   29.0  17.3
#              10    d5   27.0  14.0
#                    d14  29.5  13.0
#                    d15  28.7  10.5
#                    d28  31.2  15.0
# ...

# %%
df_weather_tidy.reset_index()
# Out:
# element       id  year  month  day  tmax  tmin
# 0        MX17004  2010      1  d30  27.8  14.5
# 1        MX17004  2010      2  d11  29.7  13.4
# 2        MX17004  2010      2   d2  27.3  14.4
# 3        MX17004  2010      2  d23  29.9  10.7
# 4        MX17004  2010      2   d3  24.1  14.4
# 5        MX17004  2010      3  d10  34.5  16.8
# 6        MX17004  2010      3  d16  31.1  17.6
# 7        MX17004  2010      3   d5  32.1  14.2
# 8        MX17004  2010      4  d27  36.3  16.7
# 9        MX17004  2010      5  d27  33.2  18.2
# 10       MX17004  2010      6  d17  28.0  17.5
# 11       MX17004  2010      6  d29  30.1  18.0
# 12       MX17004  2010      7   d3  28.6  17.5
# 13       MX17004  2010      7  d14  29.9  16.5
# 14       MX17004  2010      8  d23  26.4  15.0
# 15       MX17004  2010      8   d5  29.6  15.8
# 16       MX17004  2010      8  d29  28.0  15.3
# 17       MX17004  2010      8  d13  29.8  16.5
# 18       MX17004  2010      8  d25  29.7  15.6
# ...

# %%
df_weather
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
df_weather
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
df_weather_tidy = df_weather.pivot_table(
    
    # pivoting target columns defined
    columns = 'element'
#     columns = ['id', 'element']
#     columns = ['id', 'year', 'element']
#     columns = ['id', 'year', 'month', 'element']
    
    # not-pivoting target columns defined
#     ,index = 'id',
#     ,index = ['id', 'year'],
#     ,index = ['id', 'year', 'month'],
    
    # To define columns to provide datum of new columns
#     ,values = 'd1'
    ,values = ['d1', 'd2']
)

df_weather_tidy.head(30)
# Out:
# element  tmax   tmin
# d1       29.9  13.80
# d2       29.3  15.35

# %%
df_weather_tidy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, d1 to d2
# Data columns (total 2 columns):
# tmax    2 non-null float64
# tmin    2 non-null float64
# dtypes: float64(2)
# memory usage: 48.0+ bytes

# %%
df_weather_tidy.index
# Out:
# Index(['d1', 'd2'], dtype='object')

# %%
df_weather_tidy_flat = df_weather_tidy.reset_index()

# %%
df_weather_tidy_flat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
# index    2 non-null object
# tmax     2 non-null float64
# tmin     2 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 176.0+ bytes

# %%
df_weather_tidy_flat
# Out:
# element index  tmax   tmin
# 0          d1  29.9  13.80
# 1          d2  29.3  15.35

# %%
df_billboard = pd.read_csv('../doit_pandas/data/billboard.csv')

# %%
df_billboard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 81 columns):
# year            317 non-null int64
# artist          317 non-null object
# track           317 non-null object
# time            317 non-null object
# date.entered    317 non-null object
# wk1             317 non-null int64
# wk2             312 non-null float64
# wk3             307 non-null float64
# wk4             300 non-null float64
# wk5             292 non-null float64
# wk6             280 non-null float64
# wk7             269 non-null float64
# wk8             260 non-null float64
# wk9             253 non-null float64
# wk10            244 non-null float64
# wk11            236 non-null float64
# wk12            222 non-null float64
# wk13            210 non-null float64
# wk14            204 non-null float64
# wk15            197 non-null float64
# wk16            182 non-null float64
# wk17            177 non-null float64
# wk18            166 non-null float64
# ...

# %%
df_billboard.head()
# Out:
#    year        artist                    track  time date.entered  wk1   wk2  \
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87  82.0
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91  87.0
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08   81  70.0
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21   76  76.0
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15   57  34.0
#
#     wk3   wk4   wk5  ...  wk67  wk68  wk69  wk70  wk71  wk72  wk73  wk74  \
# 0  72.0  77.0  87.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  92.0   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  68.0  67.0  66.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  72.0  69.0  67.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  25.0  17.0  17.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    wk75  wk76
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# ...

# %%
df_billboard_long = pd.melt(
    df_billboard,
    id_vars = ['year', 'artist', 'track', 'time', 'date.entered'],
    var_name = 'week',
    value_name = 'rating'
)

df_billboard_long.head()
# Out:
#    year        artist                    track  time date.entered week  rating
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk1    87.0
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk1    91.0
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08  wk1    81.0
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21  wk1    76.0
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15  wk1    57.0

# %%
df_billboard_long[df_billboard_long.track == 'Loser']
# Out:
#        year        artist  track  time date.entered  week  rating
# 3      2000  3 Doors Down  Loser  4:24   2000-10-21   wk1    76.0
# 320    2000  3 Doors Down  Loser  4:24   2000-10-21   wk2    76.0
# 637    2000  3 Doors Down  Loser  4:24   2000-10-21   wk3    72.0
# 954    2000  3 Doors Down  Loser  4:24   2000-10-21   wk4    69.0
# 1271   2000  3 Doors Down  Loser  4:24   2000-10-21   wk5    67.0
# ...     ...           ...    ...   ...          ...   ...     ...
# 22510  2000  3 Doors Down  Loser  4:24   2000-10-21  wk72     NaN
# 22827  2000  3 Doors Down  Loser  4:24   2000-10-21  wk73     NaN
# 23144  2000  3 Doors Down  Loser  4:24   2000-10-21  wk74     NaN
# 23461  2000  3 Doors Down  Loser  4:24   2000-10-21  wk75     NaN
# 23778  2000  3 Doors Down  Loser  4:24   2000-10-21  wk76     NaN
#
# [76 rows x 7 columns]

# %%
df_billboard_songs = df_billboard_long[[
    'year', 
    'artist', 
    'track', 
    'time'
#     ,'date.entered'
]]

df_billboard_songs.shape
# Out:
# (24092, 4)

# %%
df_billboard_songs.head()
# Out:
#    year        artist                    track  time
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15
# 2  2000  3 Doors Down               Kryptonite  3:53
# 3  2000  3 Doors Down                    Loser  4:24
# 4  2000      504 Boyz            Wobble Wobble  3:35

# %%
df_billboard_songs = df_billboard_songs.drop_duplicates()
df_billboard_songs.shape
# Out:
# (317, 4)

# %%
# df_billboard_songs['id'] = range(len(df_billboard_songs))
df_billboard_songs['id'] = list(df_billboard_songs.index)

df_billboard_songs
# Out:
#      year            artist                    track  time   id
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22    0
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15    1
# 2    2000      3 Doors Down               Kryptonite  3:53    2
# 3    2000      3 Doors Down                    Loser  4:24    3
# 4    2000          504 Boyz            Wobble Wobble  3:35    4
# ..    ...               ...                      ...   ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10  312
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55  313
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19  314
# 315  2000     Zombie Nation            Kernkraft 400  3:30  315
# 316  2000   matchbox twenty                     Bent  4:12  316
#
# [317 rows x 5 columns]

# %%
df_billboard_long.head()
# Out:
#    year        artist                    track  time date.entered week  rating
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk1    87.0
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk1    91.0
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08  wk1    81.0
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21  wk1    76.0
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15  wk1    57.0

# %%
df_billboard_songs.head()
# Out:
#    year        artist                    track  time  id
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   0
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   1
# 2  2000  3 Doors Down               Kryptonite  3:53   2
# 3  2000  3 Doors Down                    Loser  4:24   3
# 4  2000      504 Boyz            Wobble Wobble  3:35   4

# %%
# df_billboard_ratings = df_billboard_long.merge(df_billboard_songs, on=['year', 'artist', 'track', 'time']) # natural join = equi join + removing duplicated columns
df_billboard_ratings = df_billboard_long.merge(df_billboard_songs)  # natural join = equi join + removing duplicated columns
# df_billboard_ratings = pd.concat([df_billboard_long, df_billboard_songs], axis = 1) # equi join

# %%
df_billboard_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24092 entries, 0 to 24091
# Data columns (total 8 columns):
# year            24092 non-null int64
# artist          24092 non-null object
# track           24092 non-null object
# time            24092 non-null object
# date.entered    24092 non-null object
# week            24092 non-null object
# rating          5307 non-null float64
# id              24092 non-null int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.7+ MB

# %%
df_billboard_ratings.shape
# Out:
# (24092, 8)

# %%
df_billboard_ratings.head()
# Out:
#    year artist                    track  time date.entered week  rating  id
# 0  2000  2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk1    87.0   0
# 1  2000  2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk2    82.0   0
# 2  2000  2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk3    72.0   0
# 3  2000  2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk4    77.0   0
# 4  2000  2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk5    87.0   0
