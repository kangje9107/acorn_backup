# %%
import pandas
df= pandas.read_csv('../doit_pandas/data/gapminder.tsv',sep='\t')

# %%
df.plot()

# %%
group1 = df.groupby(['year']).sum()
group1.loc[ :, ['pop']].plot()

# %%
df.groupby(['continent','country']).sum()
# Out:
#                            year  lifeExp        pop      gdpPercap
# continent country
# Africa    Algeria         23754  708.362  238504874   53112.311678
#           Angola          23754  454.602   87712681   43285.206346
#           Benin           23754  585.359   48209960   13864.741289
#           Botswana        23754  655.170   11654234   60378.042686
#           Burkina Faso    23754  536.328   90584127   10127.887977
# ...                         ...      ...        ...            ...
# Europe    Switzerland     23754  906.781   76611518  324892.012860
#           Turkey          23754  716.357  550908099   53633.440556
#           United Kingdom  23754  887.071  673053608  232565.675827
# Oceania   Australia       23754  895.955  175791750  239767.147610
#           New Zealand     23754  887.874   37200386  207151.473750
#
# [142 rows x 4 columns]

# %%
group2 = df.groupby(['continent','country']).sum()
group2.loc[['Africa'],['gdpPercap']].plot()

# %%
group2.loc[['Europe'],['gdpPercap']].plot()

# %%
group3=df.groupby(['year','country'])['pop','gdpPercap'].sum()
group3.loc[['Afghanistan'], : ]
# Out:
# Empty DataFrame
# Columns: [pop, gdpPercap]
# Index: []
