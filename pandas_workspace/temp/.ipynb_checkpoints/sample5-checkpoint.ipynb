# %%
import pandas as pd
df = pd.read_csv('../doit_pandas/data/gapminder.tsv',sep='\t')

# %%
#pop.head()

# %%
pop = df['pop']

# %%
pop = df.pop #pop 라는 method가 이미있어서 컬럼명과 충돌.. --> dot 연산자 비추

# %%
pop = df['pop']
pop.head()
# Out:
# 0     8425333
# 1     9240934
# 2    10267083
# 3    11537966
# 4    13079460
# Name: pop, dtype: int64

# %%
country = df.country

# %%
country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
pop.min()
# Out:
# 60011

# %%
pop.max()
# Out:
# 1318683096

# %%
pop.mean() #평균
# Out:
# 29601212.324530516

# %%
pop.median()
# Out:
# 7023595.5

# %%
pop.var()
# Out:
# 1.126949904109167e+16

# %%
pop.sum()
# Out:
# 50440465801

# %%
pop.nunique() #유니크 값 개수 -- 중복값아닌것
# Out:
# 1704

# %%
pop.quantile() #4분위 값 (default = 50%, 0~1 사이 값 넣으면 해당 분위수 값 나옴 )
# quantile() = median()
# Out:
# 7023595.5

# %%
pop.quantile(1) #100분위 값 = .max()
# Out:
# 1318683096.0

# %%
pop.kurtosis() #첨도
# Out:
# 77.94820336885383

# %%
pop.skew()
# Out:
# 8.340217715355305

# %%
pop.rank()
# Out:
# 0        943.0
# 1        999.0
# 2       1067.0
# 3       1129.0
# 4       1169.0
#          ...
# 1699     995.0
# 1700    1097.0
# 1701    1122.0
# 1702    1139.0
# 1703    1146.0
# Name: pop, Length: 1704, dtype: float64

# %%
pop.describe() # 위에서 한 요약통계량 전부 보여줌 ****
# Out:
# count    1.704000e+03
# mean     2.960121e+07
# std      1.061579e+08
# min      6.001100e+04
# 25%      2.793664e+06
# 50%      7.023596e+06
# 75%      1.958522e+07
# max      1.318683e+09
# Name: pop, dtype: float64

# %%
# ------
df.min()
# Out:
# country      Afghanistan
# continent         Africa
# year                1952
# lifeExp           23.599
# pop                60011
# gdpPercap        241.166
# dtype: object

# %%
df.sum()
# Out:
# country      AfghanistanAfghanistanAfghanistanAfghanistanAf...
# continent    AsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaAs...
# year                                                   3373068
# lifeExp                                                 101344
# pop                                                50440465801
# gdpPercap                                          1.22949e+07
# dtype: object

# %%
df.nunique()
# Out:
# country       142
# continent       5
# year           12
# lifeExp      1626
# pop          1704
# gdpPercap    1704
# dtype: int64

# %%
df.kurtosis()
# Out:
# year         -1.216832
# lifeExp      -1.126685
# pop          77.948203
# gdpPercap    27.515894
# dtype: float64

# %%
df.describe()
# Out:
#              year      lifeExp           pop      gdpPercap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165877
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846989
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %%
gdpPercap = df['gdpPercap']

# %%
country.to_json() #json 형태로 바꿔라 
#json : data를 구조적으로 저장/전달하는 포맷 ex XML, HTML, tag가 존재함. 
#<age> 19 </age> : 메타데이터의 반정형 데이터, 메타데이터가 더 큼 ;
# Out:
# '{"0":"Afghanistan","1":"Afghanistan","2":"Afghanistan","3":"Afghanistan","4":"Afghanistan","5":"Afghanistan","6":"Afghanistan","7":"Afghanistan","8":"Afghanistan","9":"Afghanistan","10":"Afghanistan","11":"Afghanistan","12":"Albania","13":"Albania","14":"Albania","15":"Albania","16":"Albania","17":"Albania","18":"Albania","19":"Albania","20":"Albania","21":"Albania","22":"Albania","23":"Albania","24":"Algeria","25":"Algeria","26":"Algeria","27":"Algeria","28":"Algeria","29":"Algeria","30":"Algeria","31":"Algeria","32":"Algeria","33":"Algeria","34":"Algeria","35":"Algeria","36":"Angola","37":"Angola","38":"Angola","39":"Angola","40":"Angola","41":"Angola","42":"Angola","43":"Angola","44":"Angola","45":"Angola","46":"Angola","47":"Angola","48":"Argentina","49":"Argentina","50":"Argentina","51":"Argentina","52":"Argentina","53":"Argentina","54":"Argentina","55":"Argentina","56":"Argentina","57":"Argentina","58":"Argentina","59":"Argentina","60":"Australia","61":"Australia","62":"Austra
# ...

# %%
country.to_list()
# Out:
# ['Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
# ...

# %%
country.to_dict()
# Out:
# {0: 'Afghanistan',
#  1: 'Afghanistan',
#  2: 'Afghanistan',
#  3: 'Afghanistan',
#  4: 'Afghanistan',
#  5: 'Afghanistan',
#  6: 'Afghanistan',
#  7: 'Afghanistan',
#  8: 'Afghanistan',
#  9: 'Afghanistan',
#  10: 'Afghanistan',
#  11: 'Afghanistan',
#  12: 'Albania',
#  13: 'Albania',
#  14: 'Albania',
#  15: 'Albania',
#  16: 'Albania',
#  17: 'Albania',
#  18: 'Albania',
#  19: 'Albania',
#  20: 'Albania',
#  21: 'Albania',
#  22: 'Albania',
#  23: 'Albania',
#  24: 'Algeria',
#  25: 'Algeria',
#  26: 'Algeria',
#  27: 'Algeria',
#  28: 'Algeria',
#  29: 'Algeria',
#  30: 'Algeria',
#  31: 'Algeria',
#  32: 'Algeria',
#  33: 'Algeria',
#  34: 'Algeria',
#  35: 'Algeria',
#  36: 'Angola',
#  37: 'Angola',
#  38: 'Angola',
#  39: 'Angola',
#  40: 'Angola',
#  41: 'Angola',
#  42: 'Angola',
#  43: 'Angola',
#  44: 'Angola',
#  45: 'Angola',
#  46: 'Angola',
#  47: 'Angola',
#  48: 'Argentina',
#  49: 'Argentina',
#  50: 'Argentina',
#  51: 'Argentina',
#  52: 'Argentina',
# ...

# %%
type(country) # Series를 frame으로 바꿔보자!
# Out:
# pandas.core.series.Series

# %%
country.to_frame()
# Out:
#           country
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 1699     Zimbabwe
# 1700     Zimbabwe
# 1701     Zimbabwe
# 1702     Zimbabwe
# 1703     Zimbabwe
#
# [1704 rows x 1 columns]

# %%
type(country.to_frame())
# Out:
# pandas.core.frame.DataFrame

# %%
country.to_string() #원래 country에 잇던걸 그대로 공백, 인덱스까지 string한거임
# Out:
# "0                    Afghanistan\n1                    Afghanistan\n2                    Afghanistan\n3                    Afghanistan\n4                    Afghanistan\n5                    Afghanistan\n6                    Afghanistan\n7                    Afghanistan\n8                    Afghanistan\n9                    Afghanistan\n10                   Afghanistan\n11                   Afghanistan\n12                       Albania\n13                       Albania\n14                       Albania\n15                       Albania\n16                       Albania\n17                       Albania\n18                       Albania\n19                       Albania\n20                       Albania\n21                       Albania\n22                       Albania\n23                       Albania\n24                       Algeria\n25                       Algeria\n26                       Algeria\n27                       Algeria\n28                       Algeria\n29         
# ...

# %%
#------groupby 배우기 위해 info로 프레임정보 확인----------------
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# continent    1704 non-null object
# year         1704 non-null int64
# lifeExp      1704 non-null float64
# pop          1704 non-null int64
# gdpPercap    1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df_groupby = df.groupby('year')

# %%
df_groupby['country'] #객체 위치 나옴

# %%
df_groupby['lifeExp'].mean() #연도별 기대수명
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df_groupby = df.groupby(['year','continent','country']) # 세분화 기준대로 세분화

# %%
df_groupby.lifeExp.mean()
# Out:
# year  continent  country
# 1952  Africa     Algeria           43.077
#                  Angola            30.015
#                  Benin             38.223
#                  Botswana          47.622
#                  Burkina Faso      31.975
#                                     ...
# 2007  Europe     Switzerland       81.701
#                  Turkey            71.777
#                  United Kingdom    79.425
#       Oceania    Australia         81.235
#                  New Zealand       80.204
# Name: lifeExp, Length: 1704, dtype: float64

# %%
df['continent'].to_json()
# Out:
# '{"0":"Asia","1":"Asia","2":"Asia","3":"Asia","4":"Asia","5":"Asia","6":"Asia","7":"Asia","8":"Asia","9":"Asia","10":"Asia","11":"Asia","12":"Europe","13":"Europe","14":"Europe","15":"Europe","16":"Europe","17":"Europe","18":"Europe","19":"Europe","20":"Europe","21":"Europe","22":"Europe","23":"Europe","24":"Africa","25":"Africa","26":"Africa","27":"Africa","28":"Africa","29":"Africa","30":"Africa","31":"Africa","32":"Africa","33":"Africa","34":"Africa","35":"Africa","36":"Africa","37":"Africa","38":"Africa","39":"Africa","40":"Africa","41":"Africa","42":"Africa","43":"Africa","44":"Africa","45":"Africa","46":"Africa","47":"Africa","48":"Americas","49":"Americas","50":"Americas","51":"Americas","52":"Americas","53":"Americas","54":"Americas","55":"Americas","56":"Americas","57":"Americas","58":"Americas","59":"Americas","60":"Oceania","61":"Oceania","62":"Oceania","63":"Oceania","64":"Oceania","65":"Oceania","66":"Oceania","67":"Oceania","68":"Oceania","69":"Oceania","70":"Oceania","
# ...

# %%
df_groupby['gdpPercap','pop','lifeExp'].mean()
# Out:
#                                   gdpPercap       pop  lifeExp
# year continent country
# 1952 Africa    Algeria          2449.008185   9279525   43.077
#                Angola           3520.610273   4232095   30.015
#                Benin            1062.752200   1738315   38.223
#                Botswana          851.241141    442308   47.622
#                Burkina Faso      543.255241   4469979   31.975
# ...                                     ...       ...      ...
# 2007 Europe    Switzerland     37506.419070   7554661   81.701
#                Turkey           8458.276384  71158647   71.777
#                United Kingdom  33203.261280  60776238   79.425
#      Oceania   Australia       34435.367440  20434176   81.235
#                New Zealand     25185.009110   4115771   80.204
#
# [1704 rows x 3 columns]

# %%
df_groupby['pop'].nunique()
# Out:
# year  continent  country
# 1952  Africa     Algeria           1
#                  Angola            1
#                  Benin             1
#                  Botswana          1
#                  Burkina Faso      1
#                                   ..
# 2007  Europe     Switzerland       1
#                  Turkey            1
#                  United Kingdom    1
#       Oceania    Australia         1
#                  New Zealand       1
# Name: pop, Length: 1704, dtype: int64

# %%
# 2번 -----------------------------------------------
from collections import OrderedDict

# %%
  dic = {
    'Name': [ 'Yoseph1', 'Yoseph2' ],
    'Occupation': [ 'Chemist', 'Statistician' ],
    'Born': [ '1990-07-21', '1991-07-07' ],
    'Died': [ '2025-07-21', '2070-07-07' ],
    'Age': [ 37, 61 ]
  }

# %%
df = pd.DataFrame( OrderedDict([
    ('Name', [ 'Yoseph1', 'Yoseph2']),
    ('Occupation', [ 'Chemist', 'Statistician' ]),
    ('Born', [ '1990-07-21', '1991-07-07' ]),
    ('Died', [ '2025-07-21', '2070-07-07' ]),
    ('Age', [ 37, 61 ])
]))

# %%
print(df)
# Out:
#       Name    Occupation        Born        Died  Age
# 0  Yoseph1       Chemist  1990-07-21  2025-07-21   37
# 1  Yoseph2  Statistician  1991-07-07  2070-07-07   61
